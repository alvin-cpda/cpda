# %% [markdown]
# # 滴滴出行A/B测试和城市运营分析

# %% [markdown]
# ## 项目背景及分析目标：数据包含滴滴出行某次A/B测试的测试结果数据和在某城市的运营数据，针对测试结果做效果分析，并以提高平台订单完成率为目标，给出平台运营建议。

# %%
import pandas as pd
test = pd.read_excel('F:\\迅雷下载\\test.xlsx') #左斜杠需要2下
from pyecharts.charts import *
import pyecharts.options as opts
from pyecharts.components import Table
from pyecharts.globals import ThemeType
from pyecharts.commons.utils import JsCode
from pyecharts.options import ComponentTitleOpts

# %% [markdown]
# ## A/B测试效果分析：在对照组和实验组分别对订单请求数，成交总额的方差和均值（t检验）进行假设检验。

# %% [markdown]
# ## 1. 计算ROI

# %%
test.head()
test.group.value_counts()
# Out:
# experiment    29
# control       29
# Name: group, dtype: int64

# %%
test.isnull().sum()
# Out:
# date                 0
# group                0
# requests             0
# gmv                  0
# coupon per trip      0
# trips                0
# canceled requests    0
# dtype: int64

# %%
test['roi']=test['gmv']/test['trips']*test['coupon per trip']

# %%
test['group'].value_counts()
# Out:
# experiment    29
# control       29
# Name: group, dtype: int64

# %% [markdown]
# ## 2. 对requests进行方差和均值的假设检验

# %%
#一共29组用t检验
requests_A=test[test.group=='control'].requests
requests_B=test[test.group=='experiment'].requests

# %%
import scipy.stats as st
st.levene(requests_A,requests_B)    #用列文检测方差齐性
# Out:
# LeveneResult(statistic=0.014685075667736849, pvalue=0.903980667108546)

# %% [markdown]
# requests均值检验

# %%
#配对样本t检验（两独立样本t检验之前需检验是否齐方差，此处不需要）

# %%
st.ttest_rel(requests_A,requests_B)
# Out:
# Ttest_relResult(statistic=1.6436140982479508, pvalue=0.11143970454099938)

# %% [markdown]
# p值大于0.05，不拒绝原假设，因此可认为实验条件对requests影响不显著。

# %% [markdown]
# ## 3. gmv的均值和方差检验

# %% [markdown]
# gmv的方差检验

# %%
gmv_a=test[test.group=='control'].gmv
gmv_b=test[test.group=='experiment'].gmv

# %%
st.levene(gmv_a,gmv_b)
# Out:
# LeveneResult(statistic=0.02865341299111212, pvalue=0.8661917430097603)

# %% [markdown]
# p值大于0.05，认为方差齐次。

# %%
st.ttest_rel(gmv_a,gmv_b)
# Out:
# Ttest_relResult(statistic=4.247583846321442, pvalue=0.00021564303983362577)

# %% [markdown]
# p值小于0.05,认为两组的gmv均值有显著差异。

# %% [markdown]
# ## 城市运营分析

# %% [markdown]
# ##  1.按时段维度分析：分析各个时段订单完成率，针对完成率低的时段结合各个时段的订单请求数，司机服务时长以及在忙率进行进一步分析。

# %%
# 各个时段订单完成率

# %%
city=pd.read_excel('F:\\迅雷下载\\city.xlsx')

# %%
city.head()
# Out:
#         date  hour  requests  trips  supply hours  average minutes of trips  \
# 0 2013-09-01    11        79     55         42.63                     20.43
# 1 2013-09-01    12        73     41         36.43                     15.53
# 2 2013-09-01    13        54     50         23.02                     17.76
# 3 2013-09-02    11       193    170         64.20                     31.47
# 4 2013-09-02    12       258    210         80.28                     38.68
#
#    pETA  aETA    utiliz
# 0  5.51  7.19  0.479240
# 1  5.48  8.48  0.426297
# 2  5.07  8.94  0.771503
# 3  5.31  6.55  0.490187
# 4  4.94  6.08  0.481814

# %%
com_hour=city.groupby(['hour'],as_index=False).agg({'trips':sum,'requests':sum}).reset_index()

# %%
com_hour['rate']=(com_hour['trips']/com_hour['requests']*100).round(2)

# %%
c = (
    Bar()
    .add_xaxis(
   com_hour['hour'].astype(str).tolist()
    )
  .add_yaxis('订单完成率',com_hour['rate'].tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="各时段订单完成率"),
    ))
    
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4e40bbf0fa61422a98e0686a1c80719f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4e40bbf0fa61422a98e0686a1c80719f = echarts.init(
#                     document.getElementById('4e40bbf0fa61422a98e0686a1c80719f'), 'white', {renderer: 'canvas'});
#                 var option_4e40bbf0fa61422a98e0686a1c80719f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u8ba2\u5355\u5b8c\u6210\u7387",
#             "legendHoverLink": true,
#             "data": [
#                 75.73,
#                 68.58,
#                 47.03
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8ba2\u5355\u5b8c\u6210\u7387"
#             ],
#             "selected": {
#                 "\u8ba2\u5355\u5b8c\u6210\u7387": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -15,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "11",
#                 "12",
#                 "13"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u65f6\u6bb5\u8ba2\u5355\u5b8c\u6210\u7387",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_4e40bbf0fa61422a98e0686a1c80719f.setOption(option_4e40bbf0fa61422a98e0686a1c80719f);
#         });
#     </script>

# %% [markdown]
# 各个时段的订单请求数

# %%
t2=city.groupby(['hour'],as_index=False).agg({'trips':sum})

# %%
c = (
    Bar()
    .add_xaxis(
   t2['hour'].astype(str).tolist()
    )
  .add_yaxis('订单总数',t2['trips'].tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="各时段订单总数"),
    ))
    
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c5893b1502044bd48ed48f7452be1a60" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c5893b1502044bd48ed48f7452be1a60 = echarts.init(
#                     document.getElementById('c5893b1502044bd48ed48f7452be1a60'), 'white', {renderer: 'canvas'});
#                 var option_c5893b1502044bd48ed48f7452be1a60 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u8ba2\u5355\u603b\u6570",
#             "legendHoverLink": true,
#             "data": [
#                 4550,
#                 5850,
#                 3085
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8ba2\u5355\u603b\u6570"
#             ],
#             "selected": {
#                 "\u8ba2\u5355\u603b\u6570": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -15,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "11",
#                 "12",
#                 "13"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u65f6\u6bb5\u8ba2\u5355\u603b\u6570",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_c5893b1502044bd48ed48f7452be1a60.setOption(option_c5893b1502044bd48ed48f7452be1a60);
#         });
#     </script>

# %% [markdown]
# 司机服务时长和司机在忙率

# %% [markdown]
# 司机在忙率

# %%
city['busy']=city['supply hours']*city['utiliz']

t4=city.groupby(['hour'],as_index=False).agg({'supply hours':sum,'busy':sum})
t4['busy_rate']=city['busy']/city['supply hours']

# %%
t4
# Out:
#    hour  supply hours     busy  busy_rate
# 0    11       1660.01   768.51   0.479240
# 1    12       1818.03  1115.28   0.426297
# 2    13       1274.60   730.83   0.771503

# %% [markdown]
# 订单完成率最低的是13点，原因但并不是订单订单总数的原因，而是司机服务时长短（最低），在忙率最高。

# %% [markdown]
# ## 2. 按日期的维度分析：分析每日的订单请求数，每日的订单完成率和每日司机在忙率，总结规律。

# %% [markdown]
# 每日的订单请求数

# %%
t5=city.groupby('date',as_index=False).agg({'requests':sum})
t5
# Out:
#          date  requests
# 0  2013-09-01       206
# 1  2013-09-02       604
# 2  2013-09-03       238
# 3  2013-09-04       199
# 4  2013-09-05       782
# 5  2013-09-06       654
# 6  2013-09-07      1432
# 7  2013-09-08       965
# 8  2013-09-09       903
# 9  2013-09-10       146
# 10 2013-09-11       685
# 11 2013-09-12       816
# 12 2013-09-13      1006
# 13 2013-09-14       887
# 14 2013-09-15       904
# 15 2013-09-16       692
# 16 2013-09-17       111
# 17 2013-09-18       162
# 18 2013-09-19      1043
# 19 2013-09-20      1227
# 20 2013-09-21      1179
# 21 2013-09-22      1060
# 22 2013-09-23       860
# 23 2013-09-24       198
# 24 2013-09-25        82
# 25 2013-09-26       279
# 26 2013-09-27      1025
# 27 2013-09-28       969
# 28 2013-09-29      1001
# 29 2013-09-30       782

# %%
c = (
    Bar()
    .add_xaxis(
   t5['date'].astype(str).tolist()
    )
  .add_yaxis('订单总数',t5['requests'].tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="各时段订单总数"),
    ))
    
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dd93fa04cdec489cbe598239ead9edd4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dd93fa04cdec489cbe598239ead9edd4 = echarts.init(
#                     document.getElementById('dd93fa04cdec489cbe598239ead9edd4'), 'white', {renderer: 'canvas'});
#                 var option_dd93fa04cdec489cbe598239ead9edd4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u8ba2\u5355\u603b\u6570",
#             "legendHoverLink": true,
#             "data": [
#                 206,
#                 604,
#                 238,
#                 199,
#                 782,
#                 654,
#                 1432,
#                 965,
#                 903,
#                 146,
#                 685,
#                 816,
#                 1006,
#                 887,
#                 904,
#                 692,
#                 111,
#                 162,
#                 1043,
#                 1227,
#                 1179,
#                 1060,
#                 860,
#                 198,
#                 82,
#                 279,
#                 1025,
#                 969,
#                 1001,
#                 782
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8ba2\u5355\u603b\u6570"
#             ],
#             "selected": {
#                 "\u8ba2\u5355\u603b\u6570": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -15,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2013-09-01",
#                 "2013-09-02",
#                 "2013-09-03",
#                 "2013-09-04",
#                 "2013-09-05",
#                 "2013-09-06",
#                 "2013-09-07",
#                 "2013-09-08",
#                 "2013-09-09",
#                 "2013-09-10",
#                 "2013-09-11",
#                 "2013-09-12",
#                 "2013-09-13",
#                 "2013-09-14",
#                 "2013-09-15",
#                 "2013-09-16",
#                 "2013-09-17",
#                 "2013-09-18",
#                 "2013-09-19",
#                 "2013-09-20",
#                 "2013-09-21",
#                 "2013-09-22",
#                 "2013-09-23",
#                 "2013-09-24",
#                 "2013-09-25",
#                 "2013-09-26",
#                 "2013-09-27",
#                 "2013-09-28",
#                 "2013-09-29",
#                 "2013-09-30"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u65f6\u6bb5\u8ba2\u5355\u603b\u6570",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_dd93fa04cdec489cbe598239ead9edd4.setOption(option_dd93fa04cdec489cbe598239ead9edd4);
#         });
#     </script>

# %% [markdown]
# 每日订单完成率分析

# %%
t6=city.groupby('date',as_index=False).agg({'requests':sum,'trips':sum})

t6['rate']=(t6['trips']/t6['requests']*100).round(2)

# %%
c = (
    Line()
    .add_xaxis(
       t6['date'].astype(str).tolist()
        )
      .add_yaxis('订单数',t6['requests'].tolist())
     .add_yaxis('订单完成率',t6['rate'].tolist(),yaxis_index=1)
     .extend_axis(
        yaxis=opts.AxisOpts(
            name="订单完成率",
            type_="value",
            axislabel_opts=opts.LabelOpts(formatter="{value}%"),
        ))
        .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="每日订单数和订单完成率"),
    
        yaxis_opts=opts.AxisOpts(
            name="点单数",
            type_="value",
            axislabel_opts=opts.LabelOpts(formatter="{value}个"
        ),
        )))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="cd71736b75b247ccbedafc95c2f5c8af" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_cd71736b75b247ccbedafc95c2f5c8af = echarts.init(
#                     document.getElementById('cd71736b75b247ccbedafc95c2f5c8af'), 'white', {renderer: 'canvas'});
#                 var option_cd71736b75b247ccbedafc95c2f5c8af = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u8ba2\u5355\u6570",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2013-09-01",
#                     206
#                 ],
#                 [
#                     "2013-09-02",
#                     604
#                 ],
#                 [
#                     "2013-09-03",
#                     238
#                 ],
#                 [
#                     "2013-09-04",
#                     199
#                 ],
#                 [
#                     "2013-09-05",
#                     782
#                 ],
#                 [
#                     "2013-09-06",
#                     654
#                 ],
#                 [
#                     "2013-09-07",
#                     1432
#                 ],
#                 [
#                     "2013-09-08",
#                     965
#                 ],
#                 [
#                     "2013-09-09",
#                     903
#                 ],
#                 [
#                     "2013-09-10",
#                     146
#                 ],
#                 [
#                     "2013-09-11",
#                     685
#                 ],
#                 [
#                     "2013-09-12",
#                     816
#                 ],
#                 [
#                     "2013-09-13",
#                     1006
#                 ],
#                 [
#                     "2013-09-14",
#                     887
#                 ],
#                 [
#                     "2013-09-15",
#                     904
#                 ],
#                 [
#                     "2013-09-16",
#                     692
#                 ],
#                 [
#                     "2013-09-17",
#                     111
#                 ],
#                 [
#                     "2013-09-18",
#                     162
#                 ],
#                 [
#                     "2013-09-19",
#                     1043
#                 ],
#                 [
#                     "2013-09-20",
#                     1227
#                 ],
#                 [
#                     "2013-09-21",
#                     1179
#                 ],
#                 [
#                     "2013-09-22",
#                     1060
#                 ],
#                 [
#                     "2013-09-23",
#                     860
#                 ],
#                 [
#                     "2013-09-24",
#                     198
#                 ],
#                 [
#                     "2013-09-25",
#                     82
#                 ],
#                 [
#                     "2013-09-26",
#                     279
#                 ],
#                 [
#                     "2013-09-27",
#                     1025
#                 ],
#                 [
#                     "2013-09-28",
#                     969
#                 ],
#                 [
#                     "2013-09-29",
#                     1001
#                 ],
#                 [
#                     "2013-09-30",
#                     782
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u8ba2\u5355\u5b8c\u6210\u7387",
#             "connectNulls": false,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2013-09-01",
#                     70.87
#                 ],
#                 [
#                     "2013-09-02",
#                     80.63
#                 ],
#                 [
#                     "2013-09-03",
#                     34.87
#                 ],
#                 [
#                     "2013-09-04",
#                     51.26
#                 ],
#                 [
#                     "2013-09-05",
#                     68.03
#                 ],
#                 [
#                     "2013-09-06",
#                     72.48
#                 ],
#                 [
#                     "2013-09-07",
#                     72.21
#                 ],
#                 [
#                     "2013-09-08",
#                     53.99
#                 ],
#                 [
#                     "2013-09-09",
#                     51.16
#                 ],
#                 [
#                     "2013-09-10",
#                     64.38
#                 ],
#                 [
#                     "2013-09-11",
#                     23.36
#                 ],
#                 [
#                     "2013-09-12",
#                     60.54
#                 ],
#                 [
#                     "2013-09-13",
#                     35.19
#                 ],
#                 [
#                     "2013-09-14",
#                     74.07
#                 ],
#                 [
#                     "2013-09-15",
#                     63.5
#                 ],
#                 [
#                     "2013-09-16",
#                     63.15
#                 ],
#                 [
#                     "2013-09-17",
#                     75.68
#                 ],
#                 [
#                     "2013-09-18",
#                     68.52
#                 ],
#                 [
#                     "2013-09-19",
#                     62.42
#                 ],
#                 [
#                     "2013-09-20",
#                     44.74
#                 ],
#                 [
#                     "2013-09-21",
#                     71.42
#                 ],
#                 [
#                     "2013-09-22",
#                     81.13
#                 ],
#                 [
#                     "2013-09-23",
#                     66.63
#                 ],
#                 [
#                     "2013-09-24",
#                     51.52
#                 ],
#                 [
#                     "2013-09-25",
#                     74.39
#                 ],
#                 [
#                     "2013-09-26",
#                     64.52
#                 ],
#                 [
#                     "2013-09-27",
#                     70.83
#                 ],
#                 [
#                     "2013-09-28",
#                     79.15
#                 ],
#                 [

# %%
city.head()
# Out:
#         date  hour  requests  trips  supply hours  average minutes of trips  \
# 0 2013-09-01    11        79     55         42.63                     20.43
# 1 2013-09-01    12        73     41         36.43                     15.53
# 2 2013-09-01    13        54     50         23.02                     17.76
# 3 2013-09-02    11       193    170         64.20                     31.47
# 4 2013-09-02    12       258    210         80.28                     38.68
#
#    pETA  aETA    utiliz   busy  busy_rate
# 0  5.51  7.19  0.479240  20.43   0.479240
# 1  5.48  8.48  0.426297  15.53   0.426297
# 2  5.07  8.94  0.771503  17.76   0.771503
# 3  5.31  6.55  0.490187  31.47   0.490187
# 4  4.94  6.08  0.481814  38.68   0.481814

# %%
t7=city.groupby('date',as_index=False).agg({'supply hours':sum,'busy':sum})
t7['busy_rate']=(t7['busy']/t7['supply hours']).round(2)

# %%
c = (
    Bar()
    .add_xaxis(
   t7['date'].astype(str).tolist()
    )
  .add_yaxis('在忙率',t7['busy_rate'].tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="各时段在忙率"),
    ))
    
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7a153d98959441218cc967d744e50cf9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7a153d98959441218cc967d744e50cf9 = echarts.init(
#                     document.getElementById('7a153d98959441218cc967d744e50cf9'), 'white', {renderer: 'canvas'});
#                 var option_7a153d98959441218cc967d744e50cf9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5728\u5fd9\u7387",
#             "legendHoverLink": true,
#             "data": [
#                 0.53,
#                 0.46,
#                 0.59,
#                 0.63,
#                 0.58,
#                 0.56,
#                 0.7,
#                 0.57,
#                 0.7,
#                 0.46,
#                 0.85,
#                 0.53,
#                 0.48,
#                 0.6,
#                 0.78,
#                 0.59,
#                 0.41,
#                 0.39,
#                 0.81,
#                 0.55,
#                 0.56,
#                 0.44,
#                 0.61,
#                 0.42,
#                 0.39,
#                 0.35,
#                 0.52,
#                 0.55,
#                 0.46,
#                 0.49
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5728\u5fd9\u7387"
#             ],
#             "selected": {
#                 "\u5728\u5fd9\u7387": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -15,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2013-09-01",
#                 "2013-09-02",
#                 "2013-09-03",
#                 "2013-09-04",
#                 "2013-09-05",
#                 "2013-09-06",
#                 "2013-09-07",
#                 "2013-09-08",
#                 "2013-09-09",
#                 "2013-09-10",
#                 "2013-09-11",
#                 "2013-09-12",
#                 "2013-09-13",
#                 "2013-09-14",
#                 "2013-09-15",
#                 "2013-09-16",
#                 "2013-09-17",
#                 "2013-09-18",
#                 "2013-09-19",
#                 "2013-09-20",
#                 "2013-09-21",
#                 "2013-09-22",
#                 "2013-09-23",
#                 "2013-09-24",
#                 "2013-09-25",
#                 "2013-09-26",
#                 "2013-09-27",
#                 "2013-09-28",
#                 "2013-09-29",
#                 "2013-09-30"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u65f6\u6bb5\u5728\u5fd9\u7387",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_7a153d98959441218cc967d744e50cf9.setOption(option_7a153d98959441218cc967d744e50cf9);
#         });
#     </script>

# %% [markdown]
# ## 3. 顾客等待时长和预计等待时长

# %%
import numpy as np
t8=city.groupby('date',as_index=False).agg({'pETA':np.mean,'aETA':np.mean})
t8[['pETA','aETA']]=t8[['pETA','aETA']].round(1)
t8
# Out:
#          date  pETA  aETA
# 0  2013-09-01   5.4   8.2
# 1  2013-09-02   5.1   6.3
# 2  2013-09-03   7.0   8.4
# 3  2013-09-04   6.7   7.6
# 4  2013-09-05   6.0   6.8
# 5  2013-09-06   6.0   7.1
# 6  2013-09-07   6.9   7.8
# 7  2013-09-08   5.8   6.9
# 8  2013-09-09   6.8   8.2
# 9  2013-09-10   6.5   7.9
# 10 2013-09-11   7.5   9.3
# 11 2013-09-12   5.7   6.2
# 12 2013-09-13   6.1   7.1
# 13 2013-09-14   5.9   6.6
# 14 2013-09-15   6.8   8.3
# 15 2013-09-16   6.2   6.9
# 16 2013-09-17   5.5   7.0
# 17 2013-09-18   5.9   7.0
# 18 2013-09-19   5.6   8.1
# 19 2013-09-20   4.1   7.1
# 20 2013-09-21   4.8   6.6
# 21 2013-09-22   4.9   5.7
# 22 2013-09-23   6.0   8.0
# 23 2013-09-24   4.7   7.9
# 24 2013-09-25   5.6   6.4
# 25 2013-09-26   4.8   6.2
# 26 2013-09-27   4.4   6.6
# 27 2013-09-28   5.2   6.2
# 28 2013-09-29   5.6   6.5
# 29 2013-09-30   5.4   6.8

# %%
c = (
    Bar()
    .add_xaxis(
   t8['date'].astype(str).tolist()
    )
  .add_yaxis('顾客预计等待时长',t8['pETA'].tolist())
    .add_yaxis('顾客实际等待时长',t8['aETA'].tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="每日顾客预计和顾客实际等待时长"),
    ))
    
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5648868f73634bb0869c9bc77963b612" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5648868f73634bb0869c9bc77963b612 = echarts.init(
#                     document.getElementById('5648868f73634bb0869c9bc77963b612'), 'white', {renderer: 'canvas'});
#                 var option_5648868f73634bb0869c9bc77963b612 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u987e\u5ba2\u9884\u8ba1\u7b49\u5f85\u65f6\u957f",
#             "legendHoverLink": true,
#             "data": [
#                 5.4,
#                 5.1,
#                 7.0,
#                 6.7,
#                 6.0,
#                 6.0,
#                 6.9,
#                 5.8,
#                 6.8,
#                 6.5,
#                 7.5,
#                 5.7,
#                 6.1,
#                 5.9,
#                 6.8,
#                 6.2,
#                 5.5,
#                 5.9,
#                 5.6,
#                 4.1,
#                 4.8,
#                 4.9,
#                 6.0,
#                 4.7,
#                 5.6,
#                 4.8,
#                 4.4,
#                 5.2,
#                 5.6,
#                 5.4
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u987e\u5ba2\u5b9e\u9645\u7b49\u5f85\u65f6\u957f",
#             "legendHoverLink": true,
#             "data": [
#                 8.2,
#                 6.3,
#                 8.4,
#                 7.6,
#                 6.8,
#                 7.1,
#                 7.8,
#                 6.9,
#                 8.2,
#                 7.9,
#                 9.3,
#                 6.2,
#                 7.1,
#                 6.6,
#                 8.3,
#                 6.9,
#                 7.0,
#                 7.0,
#                 8.1,
#                 7.1,
#                 6.6,
#                 5.7,
#                 8.0,
#                 7.9,
#                 6.4,
#                 6.2,
#                 6.6,
#                 6.2,
#                 6.5,
#                 6.8
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u987e\u5ba2\u9884\u8ba1\u7b49\u5f85\u65f6\u957f",
#                 "\u987e\u5ba2\u5b9e\u9645\u7b49\u5f85\u65f6\u957f"
#             ],
#             "selected": {
#                 "\u987e\u5ba2\u9884\u8ba1\u7b49\u5f85\u65f6\u957f": true,
#                 "\u987e\u5ba2\u5b9e\u9645\u7b49\u5f85\u65f6\u957f": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -15,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2013-09-01",
#                 "2013-09-02",
#                 "2013-09-03",
#                 "2013-09-04",
#                 "2013-09-05",
#                 "2013-09-06",
#                 "2013-09-07",
#                 "2013-09-08",
#                 "2013-09-09",
#                 "2013-09-10",
#                 "2013-09-11",
#                 "2013-09-12",
#                 "2013-09-13",
#                 "2013-09-14",
#                 "2013-09-15",
#                 "2013-09-16",
#                 "2013-09-17",
#                 "2013-09-18",
#                 "2013-09-19",
#                 "2013-09-20",
#                 "2013-09-21",
#                 "2013-09-22",
#                 "2013-09-23",
#                 "2013-09-24",
#                 "2013-09-25",
#                 "2013-09-26",
#                 "2013-09-27",
#                 "2013-09-28",
#                 "2013-09-29",
#                 "2013-09-30"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6bcf\u65e5\u987e\u5ba2\u9884\u8ba1\u548c\u987e\u5ba2\u5b9e\u9645\u7b49\u5f85\u65f6\u957f",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_5648868f73634bb0869c9bc77963b612.setOption(option_5648868f73634bb0869c9bc77963b612);
#         });
#     </script>

# %% [markdown]
# 顾客的实际等待时长都要大于预计等待时长

# %% [markdown]
# ## 重要分析结论及建议：
# 1)	实验条件对订单请求数均值影响不显著，对gmv均值有显著影响，控制组gmv均值更高。
# 2)	在13点的时段里司机订单完成率最低，但订单请求数不高，司机服务时长低，在忙绿率高，说明在该时段是可服务的司机数量少导致的。
# 3)	每日的订单完成率低谷出现在周末附近，同时周末的订单请求数，司机在忙率也是高峰，需要加大车辆在周末的投入。
# 4)	顾客实际等待时长明显大于顾客预计等待时长，应提升用户预计等待时长的准确性，优化平台派单逻辑。
